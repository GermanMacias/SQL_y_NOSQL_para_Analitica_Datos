# %% [markdown]
# <a href="https://colab.research.google.com/github/GermanMacias/SQL_y_NOSQL_para_Analitica_Datos/blob/main/cargue_base_mongodb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/GermanMacias/SQL_y_NOSQL_para_Analitica_Datos/main/Bank_Churn.csv"
df = pd.read_csv(url)
df.head()
# Out:
#    RowNumber  CustomerId  CreditScore  CountryID  GenderID  Age  Tenure  \
# 0          1    15634602          619          1         2   42       7
# 1          2    15647311          608          2         2   41       4
# 2          3    15619304          502          1         2   42       4
# 3          4    15701354          699          1         2   39       3
# 4          5    15737888          850          2         2   43       3
#
#      Balance  AccountType  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# 0       0.00            1          1               1        101348.88       1
# 1   83807.86            1          0               1        112542.58       0
# 2  159660.80            3          1               0        113931.57       1
# 3       0.00            2          0               0         93826.63       0
# 4  125510.82            1          1               1         79084.10       0
#
#      Bank DOJ
# 0  23-03-2016
# 1  09-10-2018
# 2  25-03-2019
# 3  24-10-2019
# 4  22-11-2019

# %%
# !pip install pymongo[srv]
# Out:
# Collecting pymongo[srv]
#   Downloading pymongo-4.12.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# WARNING: pymongo 4.12.1 does not provide the extra 'srv'
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo[srv])
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 7.4 MB/s eta 0:00:00
# Downloading pymongo-4.12.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 39.5 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.12.1

# %%
from pymongo import MongoClient


# URL de conexión con tu usuario y contraseña
uri = "mongodb+srv://germanmacias22dmd:wCRPzbH99DJu7Jhj@eleanub.ucfimzm.mongodb.net/?retryWrites=true&w=majority&appName=eleanub"

# Conexión al cliente
client = MongoClient(uri)
db = client["bank_data"]
coleccion = db["Bank_Churn"]

# Convertir DataFrame a lista de diccionarios
datos = df.to_dict(orient="records")

# Insertar los datos
coleccion.insert_many(datos)
# Out:
# InsertManyResult([ObjectId('6821d7e78f71a04435b7af20'), ObjectId('6821d7e78f71a04435b7af21'), ObjectId('6821d7e78f71a04435b7af22'), ObjectId('6821d7e78f71a04435b7af23'), ObjectId('6821d7e78f71a04435b7af24'), ObjectId('6821d7e78f71a04435b7af25'), ObjectId('6821d7e78f71a04435b7af26'), ObjectId('6821d7e78f71a04435b7af27'), ObjectId('6821d7e78f71a04435b7af28'), ObjectId('6821d7e78f71a04435b7af29'), ObjectId('6821d7e78f71a04435b7af2a'), ObjectId('6821d7e78f71a04435b7af2b'), ObjectId('6821d7e78f71a04435b7af2c'), ObjectId('6821d7e78f71a04435b7af2d'), ObjectId('6821d7e78f71a04435b7af2e'), ObjectId('6821d7e78f71a04435b7af2f'), ObjectId('6821d7e78f71a04435b7af30'), ObjectId('6821d7e78f71a04435b7af31'), ObjectId('6821d7e78f71a04435b7af32'), ObjectId('6821d7e78f71a04435b7af33'), ObjectId('6821d7e78f71a04435b7af34'), ObjectId('6821d7e78f71a04435b7af35'), ObjectId('6821d7e78f71a04435b7af36'), ObjectId('6821d7e78f71a04435b7af37'), ObjectId('6821d7e78f71a04435b7af38'), ObjectId('6821d7e78f71a04435b7af39'), ObjectId('6821d7e78f71a04435b7af3a'), ObjectId('6821d7e78f71a04435b7af3b'), ObjectId('6821d7e78f71a04435b7af3c'), ObjectId('6821d7e78f71a04435b7af3d'), ObjectId('6821d7e78f71a04435b7af3e'), ObjectId('6821d7e78f71a04435b7af3f'), ObjectId('6821d7e78f71a04435b7af40'), ObjectId('6821d7e78f71a04435b7af41'), ObjectId('6821d7e78f71a04435b7af42'), ObjectId('6821d7e78f71a04435b7af43'), ObjectId('6821d7e78f71a04435b7af44'), ObjectId('6821d7e78f71a04435b7af45'), ObjectId('6821d7e78f71a04435b7af46'), ObjectId('6821d7e78f71a04435b7af47'), ObjectId('6821d7e78f71a04435b7af48'), ObjectId('6821d7e78f71a04435b7af49'), ObjectId('6821d7e78f71a04435b7af4a'), ObjectId('6821d7e78f71a04435b7af4b'), ObjectId('6821d7e78f71a04435b7af4c'), ObjectId('6821d7e78f71a04435b7af4d'), ObjectId('6821d7e78f71a04435b7af4e'), ObjectId('6821d7e78f71a04435b7af4f'), ObjectId('6821d7e78f71a04435b7af50'), ObjectId('6821d7e78f71a04435b7af51'), ObjectId('6821d7e78f71a04435b7af52'), ObjectId('6821d7e78f71a04435b7af53'), ObjectId('6821d7e78f71a04435b7af54'), ObjectId('6821d7e78f71a04435b7af55'), ObjectId('6821d7e78f71a04435b7af56'), ObjectId('6821d7e78f71a04435b7af57'), ObjectId('6821d7e78f71a04435b7af58'), ObjectId('6821d7e78f71a04435b7af59'), ObjectId('6821d7e78f71a04435b7af5a'), ObjectId('6821d7e78f71a04435b7af5b'), ObjectId('6821d7e78f71a04435b7af5c'), ObjectId('6821d7e78f71a04435b7af5d'), ObjectId('6821d7e78f71a04435b7af5e'), ObjectId('6821d7e78f71a04435b7af5f'), ObjectId('6821d7e78f71a04435b7af60'), ObjectId('6821d7e78f71a04435b7af61'), ObjectId('6821d7e78f71a04435b7af62'), ObjectId('6821d7e78f71a04435b7af63'), ObjectId('6821d7e78f71a04435b7af64'), ObjectId('6821d7e78f71a04435b7af65'), ObjectId('6821d7e78f71a04435b7af66'), ObjectId('6821d7e78f71a04435b7af67'), ObjectId('6821d7e78f71a04435b7af68'), ObjectId('6821d7e78f71a04435b7af69'), ObjectId('6821d7e78f71a04435b7af6a'), ObjectId('6821d7e78f71a04435b7af6b'), ObjectId('6821d7e78f71a04435b7af6c'), ObjectId('6821d7e78f71a04435b7af6d'), ObjectId('6821d7e78f71a04435b7af6e'), ObjectId('6821d7e78f71a04435b7af6f'), ObjectId('6821d7e78f71a04435b7af70'), ObjectId('6821d7e78f71a04435b7af71'), ObjectId('6821d7e78f71a04435b7af72'), ObjectId('6821d7e78f71a04435b7af73'), ObjectId('6821d7e78f71a04435b7af74'), ObjectId('6821d7e78f71a04435b7af75'), ObjectId('6821d7e78f71a04435b7af76'), ObjectId('6821d7e78f71a04435b7af77'), ObjectId('6821d7e78f71a04435b7af78'), ObjectId('6821d7e78f71a04435b7af79'), ObjectId('6821d7e78f71a04435b7af7a'), ObjectId('6821d7e78f71a04435b7af7b'), ObjectId('6821d7e78f71a04435b7af7c'), ObjectId('6821d7e78f71a04435b7af7d'), ObjectId('6821d7e78f71a04435b7af7e'), ObjectId('6821d7e78f71a04435b7af7f'), ObjectId('6821d7e78f71a04435b7af80'), ObjectId('6821d7e78f71a04435b7af81'), ObjectId('6821d7e78f71a04435b7af82'), ObjectId('6821d7e78f71a04435b7af83'), ObjectId('6821d7e78f71a04435b7af84'), ObjectId('6821d7e78f71a04435b7af85'), ObjectId('6821d7e78f71a04435b7af86'), ObjectId('6821d7e78f71a04435b7af87'), ObjectId('6821d7e78f71a04435b7 ...

# %%
# Extraer y visualizar un documento de ejemplo de la colección
documento = coleccion.find_one() # Obtener una muestra de documento para analizar su estructura

# Mostrar muestra
from pprint import pprint
pprint(documento)
# Out:
# {'AccountType': 1,
#  'Age': 42,
#  'Balance': 0.0,
#  'Bank DOJ': '23-03-2016',
#  'CountryID': 1,
#  'CreditScore': 619,
#  'CustomerId': 15634602,
#  'EstimatedSalary': 101348.88,
#  'Exited': 1,
#  'GenderID': 2,
#  'HasCrCard': 1,
#  'IsActiveMember': 1,
#  'RowNumber': 1,
#  'Tenure': 7,
#  '_id': ObjectId('6821d7e78f71a04435b7af20')}
